# %%
#I CREATED 7 SUBCATEGORIES:
# 1) nightlife -> taken from attractions : includes ‘bar’, ‘pub’, ‘club, ‘beer’
# 2) religious -> taken from attractions : includes ‘church’, ‘synagogue’, ‘spiritual centre’, ‘mosque’
# 3) arts -> taken from attractions : includes ‘theatre’, ‘music’, ‘art’, ‘gallery’
# 4) recreational -> taken from attractions : includes ‘park’, ‘lake’, ‘garden’, ‘plaza’
# 5) sports -> taken from attractions : ‘athletics’, ‘cricket ground’, ‘tennis court’
# 6) Landmark -> taken from poi : ‘college’, ‘monument’, ‘convention’, ‘library’, ‘city hall’, ‘museum’
# 7) food -> taken from restaurants : ‘restaurant’, ‘pizza’, ‘bagel’, ‘coffee’, ‘cafe’, ‘tea’, ‘burger’, sandwich’, ‘bakery’, ‘food’, ‘chicken’, ‘fish chips’, ‘department store’, ‘dessert’, ‘noodle’

import requests
import pandas as pd
from pandas import DataFrame, Series

# %%
#GETS ALL ATTRACTIONS
url = "http://tour-pedia.org/api/getPlacesByArea?S=51.5109&N=51.5347&W=-0.1964&E=-0.0814&category=attraction"

resp = requests.get(url)
data = resp.json()

df = DataFrame(data)

# %%
df.to_csv('londonAttractionsApiCall.csv', index = False)

# %%
df = pd.read_csv('londonAttractionsApiCall.csv', usecols=['id', 'name','lat','lng', 'numReviews', 'subCategory','polarity'])                 
df.head()

df.to_csv('attractions.csv', index = False)

# %%
# A) BAR DATAFRAME
df = pd.read_csv('attractions.csv')

df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
bars = df[df.subCategory.str.lower().str.contains('bar')]
bars
# Out:
#          id        lat       lng                              name  \
# 31    38076  51.516632 -0.129230                       All Bar One
# 50    50592  51.515179 -0.151709                             Apres
# 51    43356  51.514229 -0.141148                 Aqua Roof Terrace
# 87    40585  51.531013 -0.121665                        Bar Pepito
# 100   59014  51.532111 -0.120678                         Be At One
# 125   71829  51.518050 -0.108404                            Bounce
# 155   37063  51.525987 -0.108987                         Cafe Kick
# 164   35405  51.513960 -0.157964           Carbon @ The Cumberland
# 173   36306  51.524857 -0.082144                            Casita
# 178   35507  51.533415 -0.120817                   Central Station
# 223   36527  51.512671 -0.132641                          Comptons
# 254   76593  51.516719 -0.143822                        Dar Alamar
# 277   36556  51.512256 -0.132927                Duke of Wellington
# ...

# %%
bars.head()
# Out:
#         id        lat       lng               name  numReviews  polarity  \
# 31   38076  51.516632 -0.129230        All Bar One        12.0       5.0
# 50   50592  51.515179 -0.151709              Apres        13.0       6.0
# 51   43356  51.514229 -0.141148  Aqua Roof Terrace        51.0       6.0
# 87   40585  51.531013 -0.121665         Bar Pepito        14.0       9.0
# 100  59014  51.532111 -0.120678          Be At One        14.0       5.0
#
#       subCategory
# 31            Bar
# 50   Cocktail Bar
# 51   Cocktail Bar
# 87       Wine Bar
# 100  Cocktail Bar

# %%
bars.groupby('subCategory').size()
# Out:
# subCategory
# Bar             14
# Cocktail Bar    14
# Gay Bar          5
# Hookah Bar       1
# Hotel Bar        1
# Sports Bar       3
# Whisky Bar       1
# Wine Bar         3
# dtype: int64

# %%
# B) PUB DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]

pub = df[df.subCategory.str.lower().str.contains('pub')]
pub
# Out:
#          id        lat       lng                                name  \
# 99    37227  51.512680 -0.187699                      Bayswater Arms
# 167   46355  51.532009 -0.191408                      Carlton Tavern
# 220   37246  51.517052 -0.150724                        Coach Makers
# 238   38269  51.519171 -0.140767                     Crown & Sceptre
# 255   36806  51.512145 -0.131456                             De Hems
# 265   41032  51.515727 -0.174397                      Dickens Tavern
# 275   40588  51.519423 -0.177679                         Dudley Arms
# 284   36828  51.533810 -0.099724                       Earl of Essex
# 306   60597  51.527052 -0.132227                    Euston Cider Tap
# 307   37898  51.528948 -0.126769                        Euston Flyer
# 315   38098  51.525744 -0.109976                        Exmouth Arms
# 363   82860  51.525578 -0.149242                     Frieze Art Fair
# 449   68260  51.518731 -0.121483                     Holborn Whippet
# ...

# %%
# C) CLUB DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
club = df[df.subCategory.str.lower().str.contains('club')]
club
# Out:
#          id        lat       lng                 name  numReviews  polarity  \
# 319   35515  51.519552 -0.102396               Fabric        80.0       5.0
# 454   37011  51.516209 -0.156818           Home House        40.0       7.0
# 804   65569  51.516316 -0.137122         Project Club        10.0       3.0
# 1074  37077  51.530773 -0.119948  The Big Chill House        37.0       6.0
# 1244  35311  51.528939 -0.119734       The Water Rats        17.0       5.0
# 1345  35434  51.511033 -0.129005       Zoo Bar & Club        29.0       4.0
#
#      subCategory
# 319    Nightclub
# 454    Nightclub
# 804    Nightclub
# 1074   Nightclub
# 1244   Rock Club
# 1345   Nightclub

# %%
# D) BEER DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
beer = df[df.subCategory.str.lower().str.contains('beer')]
beer
# Out:
#         id        lat       lng                name  numReviews  polarity  \
# 593  75686  51.532685 -0.178094  Ludo`s love lounge         1.0      10.0
#
#      subCategory
# 593  Beer Garden

# %%
#COMBINING A,B,C,D DATAFRAMES TOGETHER AND PRINT AS NIGHTLIFE.CSV
frames = [bars, pub, club, beer]
result = pd.concat(frames).drop_duplicates().reset_index(drop=True)
result.to_csv('nightlife.csv', index = False)

# %%
# E) CHURCH DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
church = df[df.subCategory.str.lower().str.contains('church')]
church
# Out:
#          id        lat       lng                                         name  \
# 32    40080  51.518015 -0.143187                             All Souls Church
# 117   41586  51.516514 -0.126665                    Bloomsbury Baptist Church
# 176   57663  51.517886 -0.165787  Central London Seventh Day Adventist Church
# 194   49069  51.512139 -0.100548                        Church of Scientology
# 224   75500  51.518656 -0.189490                 Comunidade Cristã em Londres
# 442   63458  51.516021 -0.181002                              Hillsong Church
# 443   40436  51.516838 -0.129721                       Hillsong Church London
# 509   56317  51.530845 -0.118593                   KXC @ The Ethiopian Church
# 522   82340  51.529902 -0.115056                          King's Cross Church
# 594   40062  51.526181 -0.122395                                 Lumen Church
# 722   79079  51.511811 -0.187516     Our Lady Queen Of Heaven Catholic Church
# ...

# %%
# F) SYNAGOGUE DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
synagogue = df[df.subCategory.str.lower().str.contains('synagogue')]
synagogue
# Out:
#          id        lat       lng                             name  numReviews  \
# 999   48170  51.533624 -0.176541  St John's Wood United Synagogue         1.0
# 1306  43767  51.515253 -0.161278            West London Synagogue         1.0
#
#       polarity subCategory
# 999        5.0   Synagogue
# 1306       5.0   Synagogue

# %%
# G) SPIRITUAL DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
spiritual = df[df.subCategory.str.lower().str.contains('spiritual')]
spiritual
# Out:
#          id        lat       lng  \
# 470   57190  51.517033 -0.167891
# 578   42324  51.526055 -0.122812
# 1005  35745  51.519981 -0.162395
#
#                                                    name  numReviews  polarity  \
# 470   Igreja Adventista do Sétimo Dia Central de Lon...         1.0       0.0
# 578                           London Ikeda Peace Centre         1.0      10.0
# 1005                                   St Mary's Church         2.0       5.0
#
#            subCategory
# 470   Spiritual Center
# 578   Spiritual Center
# 1005  Spiritual Center

# %%
# H) MOSQUE DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
mosque = df[df.subCategory.str.lower().str.contains('mosque')]
mosque
# Out:
#          id        lat       lng                             name  numReviews  \
# 448   48910  51.519412 -0.111631  Holborn Muslim Community Centre         3.0
# 488   60148  51.528603 -0.164726          Islamic Cultural Centre         1.0
# 572   49338  51.528851 -0.165439            London Central Mosque         2.0
# 1161  35566  51.528909 -0.165191        The London Central Mosque        16.0
#
#       polarity subCategory
# 448        3.0      Mosque
# 488        5.0      Mosque
# 572        3.0      Mosque
# 1161       3.0      Mosque

# %%
# COMBINE E,F,G,H DATAFRAMES AND PRINT AS RELIGIOUS.CSV
religious_frames = [church, synagogue, spiritual, mosque]
religious_result = pd.concat(religious_frames)
religious_result.to_csv('religious.csv', index = False) 
religious_result

# %%
# I) THEATER DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
theater = df[df.subCategory.str.lower().str.contains('theater')]
theater
# Out:
#          id        lat       lng                                  name  \
# 119   35987  51.525064 -0.132597                    Bloomsbury Theatre
# 159   36023  51.513658 -0.126754                     Cambridge Theatre
# 162   36541  51.521001 -0.184321                    Canal Cafe Theatre
# 601   67301  51.522354 -0.157150                    Madame Tussaude 4D
# 687   36024  51.512255 -0.119291                       Novello Theatre
# 700   35976  51.513576 -0.159971                                 Odeon
# 740   35965  51.513223 -0.129604                        Palace Theatre
# 754   35966  51.514427 -0.118070                       Peacock Theatre
# 817   35968  51.511761 -0.132480                       Queen's Theatre
# 848   46317  51.528429 -0.154723        Regent's Park Open Air Theatre
# 1097  36049  51.524572 -0.169540                           The Cockpit
# 1165  75428  51.514946 -0.188522                            The Lounge
# ...

# %%
# J) MUSIC DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
music = df[df.subCategory.str.lower().str.contains('music')]
music
# Out:
#          id        lat       lng                   name  numReviews  polarity  \
# 90    49631  51.519475 -0.093847  Barbican Concert Hall         3.0       8.0
# 824   37981  51.534213 -0.167538            RAK Studios         1.0      10.0
# 1334  49573  51.525447 -0.085962            XOYO London        35.0       6.0
#
#       subCategory
# 90    Music Venue
# 824   Music Venue
# 1334  Music Venue

# %%
# K) ART DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
art = df[df.subCategory.str.lower().str.contains('art')]
art
# Out:
#          id        lat       lng                         name  numReviews  \
# 363   82860  51.525578 -0.149242              Frieze Art Fair         3.0
# 973   36089  51.511782 -0.143713                    Sotheby's        11.0
# 1056  79042  51.516501 -0.175551  Temple Studios (Punchdrunk)        25.0
# 1144  36293  51.514752 -0.124712            The Hospital Club        82.0
# 1197  47095  51.531095 -0.119686              The Poor School         1.0
#
#       polarity            subCategory
# 363       10.0             Public Art
# 973        7.0            Art Gallery
# 1056       7.0  Performing Arts Venue
# 1144       7.0  Performing Arts Venue
# 1197      10.0  Performing Arts Venue

# %%
# L) CONCERT DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]

concert = df[df.subCategory.str.lower().str.contains('concert')]
concert
# Out:
#         id        lat       lng         name  numReviews  polarity  \
# 710  47471  51.513125 -0.153007  One Mayfair         2.0       8.0
#
#       subCategory
# 710  Concert Hall

# %%
# COMBINE I,J,K,L AND PRINT AS ARTS.CSV
art_frames = [theater, music, art, concert]
art_result = pd.concat(art_frames)
art_result.to_csv('arts.csv', index = False) 
art_result
# Out:
#          id        lat       lng                                  name  \
# 119   35987  51.525064 -0.132597                    Bloomsbury Theatre
# 159   36023  51.513658 -0.126754                     Cambridge Theatre
# 162   36541  51.521001 -0.184321                    Canal Cafe Theatre
# 601   67301  51.522354 -0.157150                    Madame Tussaude 4D
# 687   36024  51.512255 -0.119291                       Novello Theatre
# 700   35976  51.513576 -0.159971                                 Odeon
# 740   35965  51.513223 -0.129604                        Palace Theatre
# 754   35966  51.514427 -0.118070                       Peacock Theatre
# 817   35968  51.511761 -0.132480                       Queen's Theatre
# 848   46317  51.528429 -0.154723        Regent's Park Open Air Theatre
# 1097  36049  51.524572 -0.169540                           The Cockpit
# 1165  75428  51.514946 -0.188522                            The Lounge
# ...

# %%
# M) PARK DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
park = df[df.subCategory.str.lower().str.contains('park')]
park
# Out:
#         id        lat       lng                                   name  \
# 147  38888  51.523484 -0.088534                         Bunhill Fields
# 174  43545  51.516543 -0.144965                Cavendish Square Garden
# 745  44635  51.524392 -0.146942                    Park Square Gardens
# 843  38126  51.527489 -0.153712                          Regent's Park
# 845  43039  51.524874 -0.157567  Regent's Park (Baker Street entrance)
# 847  57383  51.534110 -0.162756               Regent's Park North Gate
# 986  53215  51.526136 -0.146653                       St Andrew's Gate
#
#      numReviews  polarity subCategory
# 147        16.0       7.0        Park
# 174         9.0       7.0        Park
# 745         1.0       5.0        Park
# 843        85.0       6.0        Park
# 845        16.0       7.0        Park
# 847         2.0      10.0        Park
# 986         1.0       0.0        Park

# %%
#N) LAKE DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
lake = df[df.subCategory.str.lower().str.contains('lake')]
lake
# Out:
#         id        lat       lng                name  numReviews  polarity  \
# 122  42536  51.528611 -0.160997        Boating Lake         4.0       8.0
# 846  46663  51.527276 -0.158787  Regent's Park Lake        12.0       6.0
#
#     subCategory
# 122        Lake
# 846        Lake

# %%
# O) GARDEN DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
garden = df[df.subCategory.str.lower().str.contains('garden')]
garden
# Out:
#         id        lat       lng                    name  numReviews  polarity  \
# 235  72739  51.512866 -0.182678     Craven Hill Gardens         1.0      10.0
# 546  70883  51.511757 -0.175159          Lancaster Gate         5.0       8.0
# 593  75686  51.532685 -0.178094      Ludo`s love lounge         1.0      10.0
# 800  46737  51.512962 -0.192196          Princes Square         1.0       5.0
# 815  36917  51.521599 -0.122393            Queen Square         3.0       3.0
# 879  76756  51.521632 -0.125840  Russell Square Gardens         8.0       8.0
#
#      subCategory
# 235       Garden
# 546       Garden
# 593  Beer Garden
# 800       Garden
# 815       Garden
# 879       Garden

# %%
# P) ZOO DATAFRAME 
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
df.head()

zoo = df[df.subCategory.str.lower().str.contains('zoo')]
zoo
# Out:
# Empty DataFrame
# Columns: [id, lat, lng, name, numReviews, polarity, subCategory]
# Index: []

# %%
# Q) HARBOR DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
df.head()

harbor = df[df.subCategory.str.lower().str.contains('harbor')]
harbor
# Out:
#         id        lat       lng              name  numReviews  polarity  \
# 565  35690  51.522576 -0.187669     Little Venice        18.0       7.0
# 734  50462  51.518437 -0.173850  Paddington Basin         5.0       2.0
# 852  59892  51.534439 -0.093214     Regents Canal         4.0       6.0
#
#          subCategory
# 565  Harbor / Marina
# 734  Harbor / Marina
# 852  Harbor / Marina

# %%
# R) PLAZA DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
plaza = df[df.subCategory.str.lower().str.contains('plaza')]
plaza

# %%
# COMBINE M,N,O,P,Q,R AND PRINT AS RECREATIONAL.CSV
recreational_frames = [park, lake, garden, harbor, plaza]
recreational_result = pd.concat(recreational_frames)
recreational_result.to_csv('recreational.csv', index = False) 
recreational_result
# Out:
#         id        lat       lng                                   name  \
# 147  38888  51.523484 -0.088534                         Bunhill Fields
# 174  43545  51.516543 -0.144965                Cavendish Square Garden
# 745  44635  51.524392 -0.146942                    Park Square Gardens
# 843  38126  51.527489 -0.153712                          Regent's Park
# 845  43039  51.524874 -0.157567  Regent's Park (Baker Street entrance)
# 847  57383  51.534110 -0.162756               Regent's Park North Gate
# 986  53215  51.526136 -0.146653                       St Andrew's Gate
# 122  42536  51.528611 -0.160997                           Boating Lake
# 846  46663  51.527276 -0.158787                     Regent's Park Lake
# 235  72739  51.512866 -0.182678                    Craven Hill Gardens
# 546  70883  51.511757 -0.175159                         Lancaster Gate
# 593  75686  51.532685 -0.178094                     Ludo`s love lounge
# ...

# %%
# S) ATHLETICS DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
athletics = df[df.subCategory.str.lower().str.contains('athletics')]
athletics
# Out:
#         id        lat       lng                   name  numReviews  polarity  \
# 588  66988  51.530125 -0.170171  Lords Cricket Academy         1.0       0.0
#
#             subCategory
# 588  Athletics & Sports

# %%
# T) CRICKET DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
cricket = df[df.subCategory.str.lower().str.contains('cricket')]
cricket
# Out:
#         id        lat       lng                         name  numReviews  \
# 585  36007  51.529412 -0.172691  Lord's Cricket Ground (MCC)        41.0
# 586  46308  51.529062 -0.173527              Lord's Pavilion         1.0
#
#      polarity     subCategory
# 585       6.0  Cricket Ground
# 586       5.0  Cricket Ground

# %%
# ) COURT DATAFRAME
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
court = df[df.subCategory.str.lower().str.contains('court')]
court
# Out:
#         id        lat      lng                         name  numReviews  \
# 849  44751  51.525574 -0.15348  Regent's Park Tennis Courts         3.0
#
#      polarity   subCategory
# 849       8.0  Tennis Court

# %%
# COMBINE S,T,U DATAFRAMES AND PRINT AS SPORTS.CSV
sports_frames = [athletics, cricket, court]
sports_result = pd.concat(sports_frames)
sports_result.to_csv('sports.csv', index = False) 
sports_result
# Out:
#         id        lat       lng                         name  numReviews  \
# 588  66988  51.530125 -0.170171        Lords Cricket Academy         1.0
# 585  36007  51.529412 -0.172691  Lord's Cricket Ground (MCC)        41.0
# 586  46308  51.529062 -0.173527              Lord's Pavilion         1.0
# 849  44751  51.525574 -0.153480  Regent's Park Tennis Courts         3.0
#
#      polarity         subCategory
# 588       0.0  Athletics & Sports
# 585       6.0      Cricket Ground
# 586       5.0      Cricket Ground
# 849       8.0        Tennis Court

# %%
#GETS ALL FOOD PLACES IN LONDON

url = "http://tour-pedia.org/api/getPlacesByArea?S=51.5109&N=51.5347&W=-0.1964&E=-0.0814&category=restaurant"

resp = requests.get(url)
data = resp.json()

df = DataFrame(data)

df.to_csv('londonRestaurantsApiCall.csv', index = False)
df = pd.read_csv('londonRestaurantsApiCall.csv', usecols=['id', 'name','lat','lng', 'numReviews', 'subCategory','polarity'])                 
df.head()

df.to_csv('restaurants.csv', index = False) 

df = pd.read_csv('restaurants.csv')

#FILTER THE RESTAURANTS; ONLY GET PLACES WITH REVIEWS/POLARITY SCORES

df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
restaurant = df[df.subCategory.str.lower().str.contains('restaurant')]
restaurant
# Out:
#          id        lat       lng                            name  numReviews  \
# 14    48311  51.515456 -0.163524               118 Edgeware Road         3.0
# 39    80006  51.515402 -0.191269                         65&King         3.0
# 61    42750  51.514480 -0.175036                     ASK Italian         9.0
# 544   59376  51.526288 -0.084715        Best Mangal Kebab & Café        15.0
# 774   70271  51.526300 -0.084375                      Bánh Mì 11        18.0
# 780   41769  51.515450 -0.191682                  C&R Restaurant        21.0
# 943   56117  51.511291 -0.128502                      Café Fiori        26.0
# 1229  78816  51.514907 -0.098554                    Coco di Mama         1.0
# 1350  50749  51.515133 -0.194057                  Cote Brasserie        21.0
# 1860  41166  51.512848 -0.187650             Four Seasons | 文興酒家        53.0
# 2495  63320  51.521575 -0.109885                 KIN Street Food        20.0
# ...

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
pizza = df[df.subCategory.str.lower().str.contains('pizza')]
pizza
# Out:
#          id        lat       lng                        name  numReviews  \
# 60    47540  51.513429 -0.155755                 ASK Italian         8.0
# 2379  36152  51.519452 -0.135999  Italiano Coffee Co. (ICCo)        63.0
#
#       polarity  subCategory
# 60         7.0  Pizza Place
# 2379       7.0  Pizza Place

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
bagel = df[df.subCategory.str.lower().str.contains('bagel')]
bagel
# Out:
#         id        lat       lng           name  numReviews  polarity  \
# 357  57373  51.516526 -0.176663  Bagel Factory         5.0       3.0
#
#     subCategory
# 357  Bagel Shop

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
coffee = df[df.subCategory.str.lower().str.contains('coffee')]
coffee
# Out:
#          id        lat       lng                                  name  \
# 473   80484  51.532161 -0.125045                             Beanstalk
# 919   36185  51.517770 -0.166491                            Caffe Nero
# 936   36244  51.516207 -0.119537                            Caffè Nero
# 940   44970  51.531720 -0.126188                            Caffè Nero
# 1315  43339  51.516596 -0.174004                          Costa Coffee
# 1334  40310  51.532022 -0.122401                          Costa Coffee
# 2172  79229  51.511532 -0.089522                        Harris + Hoole
# 3363  61348  51.512412 -0.120938                                 Notes
# 3588  80766  51.527695 -0.190622                            Petit Café
# 4162  62758  51.515080 -0.121647         Salt Espresso Lunch & Tea Bar
# 4463  37126  51.512464 -0.104256                             Starbucks
# 4465  39052  51.513016 -0.153626                             Starbucks
# ...

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
cafe = df[df.subCategory.str.lower().str.contains('café')]
cafe
# Out:
#          id        lat       lng                           name  numReviews  \
# 569   53323  51.512508 -0.126750           Bill's Produce Store        57.0
# 1362  44440  51.525687 -0.154195              Cow & Coffee Bean         7.0
# 3168  73670  51.525500 -0.179464  Molly's Cafe At Little Venice         3.0
# 3233  81418  51.518357 -0.167143                  MyCircle Café         2.0
# 4415  50291  51.526163 -0.136480                  Speedy's Cafe        11.0
# 4848  36702  51.525938 -0.160918                 The Bite @ LBS         2.0
# 5094  43099  51.532499 -0.157983                        The Hub         2.0
# 5571  77835  51.516606 -0.173969                  Victor's Café         1.0
#
#       polarity subCategory
# 569        6.0        Café
# 1362       5.0        Café
# 3168       7.0        Café
# 3233       5.0        Café
# 4415       8.0        Café
# 4848       8.0        Café
# 5094      10.0        Café
# 5571       5.0        Café

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
tea = df[df.subCategory.str.lower().str.contains('tea')]
tea
# Out:
#          id        lat       lng         name  numReviews  polarity  \
# 720   55634  51.512048 -0.133386  Bubbleology        61.0       7.0
# 2185  50780  51.513475 -0.125748    Hawksmoor       118.0       7.0
# 5506  36090  51.513390 -0.113170     Twinings        15.0       6.0
# 5815  37074  51.515046 -0.136299      Yumchaa        67.0       7.0
#
#      subCategory
# 720     Tea Room
# 2185  Steakhouse
# 5506    Tea Room
# 5815    Tea Room

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
burger = df[df.subCategory.str.lower().str.contains('burger')]
burger
# Out:
#         id        lat       lng   name  numReviews  polarity   subCategory
# 762  45029  51.512014 -0.120699  Byron        57.0       6.0  Burger Joint
# 763  38165  51.512989 -0.133681  Byron        79.0       7.0  Burger Joint
# 764  68569  51.515206 -0.192540  Byron        11.0       7.0  Burger Joint
# 766  75502  51.520186 -0.103877  Byron         8.0       6.0  Burger Joint

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
sandwich = df[df.subCategory.str.lower().str.contains('sandwich')]
sandwich
# Out:
#          id       lat       lng  name  numReviews  polarity     subCategory
# 1585  37669  51.51833 -0.112224  EAT.         6.0       7.0  Sandwich Place

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
bakery = df[df.subCategory.str.lower().str.contains('bakery')]
bakery
# Out:
#          id        lat       lng                   name  numReviews  polarity  \
# 1943  51744  51.525858 -0.109222  Gail's Artisan Bakery        19.0       6.0
# 3538  62372  51.519417 -0.169008     Patisserie Valerie        21.0       7.0
# 3549  73314  51.515822 -0.119356                   Paul         4.0      10.0
#
#      subCategory
# 1943      Bakery
# 3538      Bakery
# 3549      Bakery

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
food = df[df.subCategory.str.lower().str.contains('food')]
food
# Out:
#          id        lat       lng               name  numReviews  polarity  \
# 2049  78395  51.534417 -0.124787  Good & Proper Tea         5.0       9.0
# 2488  61649  51.534484 -0.124154            KERB KX        17.0       6.0
# 2769  66165  51.531471 -0.124197               Leon        30.0       7.0
# 3052  45105  51.513403 -0.159173         McDonald's        15.0       4.0
# 3058  42071  51.517603 -0.082349         McDonald's        12.0       5.0
# 3064  49170  51.533654 -0.108448         McDonald's         5.0       7.0
#
#                subCategory
# 2049            Food Truck
# 2488            Food Truck
# 2769  Fast Food Restaurant
# 3052  Fast Food Restaurant
# 3058  Fast Food Restaurant
# 3064  Fast Food Restaurant

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
chicken = df[df.subCategory.str.lower().str.contains('chicken')]
chicken
# Out:
#          id        lat       lng name  numReviews  polarity  \
# 2489  44046  51.513582 -0.158068  KFC        19.0       5.0
#
#               subCategory
# 2489  Fried Chicken Joint

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
fishchips = df[df.subCategory.str.lower().str.contains('fish & chips')]
fishchips
# Out:
#          id        lat       lng                  name  numReviews  polarity  \
# 3122  45104  51.517043 -0.172863  Micky's Fish & Chips         5.0       9.0
#
#             subCategory
# 3122  Fish & Chips Shop

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
dep = df[df.subCategory.str.lower().str.contains('department store')]
dep
# Out:
#          id        lat       lng             name  numReviews  polarity  \
# 2992  36699  51.515596 -0.138102  Marks & Spencer        20.0       7.0
# 2993  41517  51.519559 -0.168400  Marks & Spencer        10.0       7.0
#
#            subCategory
# 2992  Department Store
# 2993  Department Store

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
dessert = df[df.subCategory.str.lower().str.contains('dessert')]
dessert
# Out:
#          id        lat       lng                     name  numReviews  \
# 3641  59264  51.514637 -0.154106                Pinkberry        17.0
# 4361  76529  51.532287 -0.169029  Snog Pure Frozen Yogurt         1.0
#
#       polarity   subCategory
# 3641       8.0  Dessert Shop
# 4361      10.0  Dessert Shop

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
noodle = df[df.subCategory.str.lower().str.contains('noodle')]
noodle
# Out:
#          id        lat       lng      name  numReviews  polarity  \
# 5619  75232  51.516902 -0.120249  Wagamama         7.0       5.0
#
#                 subCategory
# 5619  Ramen /  Noodle House

# %%
#COMBINE ALL THE FOOD PLACE DATAFRAMES TOGETHER AND OUTPUT AS FOOD.CSV
food_frames = [restaurant, pizza, burger, coffee, cafe, tea, burger, sandwich, bakery, food, chicken, fishchips, dep, dessert, noodle]
food_result = pd.concat(food_frames).drop_duplicates().reset_index(drop=True)
food_result.to_csv('food.csv', index = False) 
food_result
# Out:
#        id        lat       lng                                  name  \
# 0   48311  51.515456 -0.163524                     118 Edgeware Road
# 1   80006  51.515402 -0.191269                               65&King
# 2   42750  51.514480 -0.175036                           ASK Italian
# 3   59376  51.526288 -0.084715              Best Mangal Kebab & Café
# 4   70271  51.526300 -0.084375                            Bánh Mì 11
# 5   41769  51.515450 -0.191682                        C&R Restaurant
# 6   56117  51.511291 -0.128502                            Café Fiori
# 7   78816  51.514907 -0.098554                          Coco di Mama
# 8   50749  51.515133 -0.194057                        Cote Brasserie
# 9   41166  51.512848 -0.187650                   Four Seasons | 文興酒家
# 10  63320  51.521575 -0.109885                       KIN Street Food
# 11  52062  51.513546 -0.127160              Kopapa Cafe & Restaurant
# 12  66165  51.531471 -0.124197                                  Leon
# ...

# %%
#GETS ALL THE POINT OF INTEREST IN LONDON
url = "http://tour-pedia.org/api/getPlacesByArea?S=51.5109&N=51.5347&W=-0.1964&E=-0.0814&category=poi"

resp = requests.get(url)
data = resp.json()

df = DataFrame(data)

df.to_csv('londonPoiApiCall.csv', index = False)
df = pd.read_csv('londonPoiApiCall.csv', usecols=['id', 'name','lat','lng', 'numReviews', 'subCategory','polarity'])                 
df.head()

df.to_csv('poi.csv', index = False) 

df = pd.read_csv('poi.csv')

df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
museum = df[df.subCategory.str.lower().str.contains('museum')]
museum
# Out:
#          id        lat       lng                            name  numReviews  \
# 408   35537  51.514193 -0.087281          Bank of England Museum        12.0
# 3550  35617  51.522310 -0.103044  Museum of the Order of St John         5.0
#
#       polarity     subCategory
# 408        5.0          Museum
# 3550       8.0  History Museum

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
university = df[df.subCategory.str.lower().str.contains('university')]
university
# Out:
#         id        lat       lng             name  numReviews  polarity  \
# 104  57246  51.525954 -0.155032  Acland Building         1.0      10.0
#
#                       subCategory
# 104  General College & University

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
library = df[df.subCategory.str.lower().str.contains('library')]
library
# Out:
#          id        lat       lng                                      name  \
# 3071  48532  51.525370 -0.107544              London Metropolitan Archives
# 3305  47868  51.521411 -0.159552                        Marylebone Library
# 4244  72009  51.522297 -0.122916                      Queen Square Library
# 4467  43198  51.522666 -0.128881                              SOAS Library
# 5175  55651  51.530635 -0.127401  The British Library Business & IP Centre
# 5312  78435  51.515101 -0.111786                   The Law Society Library
# 5602  38414  51.524853 -0.133608                          UCL Main Library
#
#       numReviews  polarity      subCategory
# 3071         2.0       8.0          Library
# 3305         1.0      10.0          Library
# 4244         1.0      10.0          Library
# 4467         5.0       6.0  College Library
# 5175         2.0       8.0          Library
# 5312         1.0       5.0          Library
# 5602         6.0       6.0  College Library

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
monument = df[df.subCategory.str.lower().str.contains('monument')]
monument
# Out:
#          id        lat       lng                           name  numReviews  \
# 265   44750  51.510906 -0.157285        Animals In War Memorial         1.0
# 363   35561  51.521485 -0.138858                       BT Tower        11.0
# 521   53751  51.514613 -0.081940                    Bishopsgate         1.0
# 1865  53641  51.517903 -0.105143              Farringdon Street         1.0
# 2158  78350  51.528507 -0.163290             H. G. Wells' House         1.0
# 2968  48118  51.512082 -0.129714  London Chinatown Peace Pagoda         1.0
# 3123  35700  51.514753 -0.099213          London Stock Exchange        14.0
# 3841  46632  51.516346 -0.176623         Paddington Bear Statue        16.0
# 4620  53239  51.522389 -0.156996         Sherlock Holmes Statue         3.0
# 4960  35709  51.514227 -0.101543               Stationers' Hall         1.0
# 4961  43710  51.525073 -0.129025               Statue of Gandhi         1.0
# ...

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
convention = df[df.subCategory.str.lower().str.contains('convention')]
convention
# Out:
#          id        lat       lng                               name  \
# 667   53637  51.529288 -0.127121  British Library Conference Centre
# 739   45692  51.516326 -0.129459                                CBI
# 1198  65192  51.517200 -0.163030                  Convention center
# 1341  40957  51.518104 -0.110570                     De Vere Venues
# 2093  39545  51.515744 -0.120428              Grand Connaught Rooms
# 2316  49834  51.520706 -0.153709                    Hellenic Centre
# 2479  62080  51.517872 -0.137036              ICO Conference Centre
# 5180  53495  51.519546 -0.132066                The Building Centre
# 5785  37657  51.525487 -0.134883                     Wellcome Trust
#
#       numReviews  polarity        subCategory
# 667          1.0       5.0  Convention Center
# 739          3.0       2.0  Convention Center
# 1198         1.0       5.0  Convention Center
# 1341         1.0      10.0  Convention Center
# 2093         9.0       9.0  Convention Center
# ...

# %%
df = df[(df.numReviews > 0) & (~(df.subCategory.isna())) & (~(df.polarity.isna()))]
cityhall = df[df.subCategory.str.lower().str.contains('city hall')]
cityhall
# Out:
#          id        lat       lng                      name  numReviews  \
# 771   39556  51.528971 -0.125506          Camden Town Hall         5.0
# 3730  44671  51.521571 -0.159845  Old Marylebone Town Hall         2.0
# 5556  51884  51.529405 -0.124905       Town Hall Extension         4.0
#
#       polarity subCategory
# 771        3.0   City Hall
# 3730       5.0   City Hall
# 5556       6.0   City Hall

# %%
#COMBINE ALL POI DATAFRAMES AS ONE AND PRINT AS LANDMARK.CSV
landmark_frames = [university, museum, library, monument, convention, cityhall]
landmark_result = pd.concat(landmark_frames)
landmark_result.to_csv('landmark.csv', index = False) 
landmark_result
# Out:
#          id        lat       lng                                      name  \
# 104   57246  51.525954 -0.155032                           Acland Building
# 408   35537  51.514193 -0.087281                    Bank of England Museum
# 3550  35617  51.522310 -0.103044            Museum of the Order of St John
# 3071  48532  51.525370 -0.107544              London Metropolitan Archives
# 3305  47868  51.521411 -0.159552                        Marylebone Library
# 4244  72009  51.522297 -0.122916                      Queen Square Library
# 4467  43198  51.522666 -0.128881                              SOAS Library
# 5175  55651  51.530635 -0.127401  The British Library Business & IP Centre
# 5312  78435  51.515101 -0.111786                   The Law Society Library
# 5602  38414  51.524853 -0.133608                          UCL Main Library
# 265   44750  51.510906 -0.157285                   Animals In War Memorial
# ...

# %%
#1)NIGHTLIFE REVIEWS
new = []
for index, row in result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
nightlife_reviews = DataFrame(new).stack().apply(pd.Series)
nightlife_reviews.to_csv('nightlife_reviews.csv', index = False)
# Out:
# [[{'language': 'et',
#    'polarity': 0,
#    'rating': 0,
#    'source': 'Foursquare',
#    'text': 'gorgeous halloumi salad',
#    'time': '2011-01-20',
#    'wordsCount': 3,
#    'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73b6eae9eef5a5065168d'},
#   {'language': 'en',
#    'polarity': 10,
#    'rating': 0,
#    'source': 'Foursquare',
#    'text': 'Great food, excellent selection of beer and wine and great service.',
#    'time': '2011-01-25',
#    'wordsCount': 11,
#    'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73b6eae9eef5a5065168e'},
#   {'language': 'en',
#    'polarity': 5,
#    'rating': 0,
#    'source': 'Foursquare',
#    'text': 'Slow service, you might not get what you order food wise... Good booze tho!',
#    'time': '2011-02-25',
#    'wordsCount': 14,
#    'details': 'http://tour-pedia.org/api/getReviewDetails?id=52a73b6eae9eef5a5065168f'},
#   {'language': 'en',
#    'polarity': 0,
#    'rating': 0,
#    'source': 'Foursquare',
# ...

# %%
#2)RELIGIOUS REVIEWS
new = []
for index, row in religious_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
religious_reviews = DataFrame(new).stack().apply(pd.Series)
religious_reviews.to_csv('religious_reviews.csv', index = False)

# %%
#3)ART/MUSIC REVIEWS
new = []
for index, row in art_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
arts_reviews = DataFrame(new).stack().apply(pd.Series)
arts_reviews.to_csv('arts_reviews.csv', index = False)

# %%
#4)RECREATIONAL REVIEWS
new = []
for index, row in recreational_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
recreational_reviews = DataFrame(new).stack().apply(pd.Series)
recreational_reviews.to_csv('recreational_reviews.csv', index = False)

# %%
#5)SPORTS REVIEWS
new = []
for index, row in sports_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
sports_reviews = DataFrame(new).stack().apply(pd.Series)
sports_reviews.to_csv('sports_reviews.csv', index = False)

# %%
#6)LANDMARK/POI REVIEWS
new = []
for index, row in landmark_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
landmark_reviews = DataFrame(new).stack().apply(pd.Series)
landmark_reviews.to_csv('landmark_reviews.csv', index = False)

# %%
#7)FOOD REVIEWS
new = []
for index, row in food_result.iterrows():
    review_url = requests.get('http://tour-pedia.org/api/getReviewsByPlaceId?placeId={}'.format(row['id']))
    data = review_url.json()
    new.append(data)
food_reviews = DataFrame(new).stack().apply(pd.Series)
food_reviews.to_csv('food_reviews.csv', index = False)
